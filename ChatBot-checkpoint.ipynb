# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\yknld\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\yknld\anaconda3\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\yknld\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yknld\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\yknld\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def chatbot():
    print("🤖 Chatbot: Hello! Type 'bye' to exit")

    while True:
        user = input("You: ").lower()

        if "hello" in user or "hi" in user:
            print("Chatbot: Hi there! 😊")
        elif "how are you" in user:
            print("Chatbot: I'm doing great!")
        elif "name" in user:
            print("Chatbot: I am CodSoft Bot 🤖")
        elif "help" in user:
            print("Chatbot: I can answer basic questions!")
        elif "bye" in user:
            print("Chatbot: Goodbye 👋")
            break
        else:
            print("Chatbot: Sorry, I didn't understand that.")

chatbot()
# Out:
# 🤖 Chatbot: Hello! Type 'bye' to exit
# You:  Hello
# Chatbot: Hi there! 😊
# You:  How are you?
# Chatbot: I'm doing great!
# You:  Can i get some update?
# Chatbot: Sorry, I didn't understand that.
# You:  Bye
# Chatbot: Goodbye 👋
